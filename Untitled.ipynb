# %%
# QUESTION 01
# Make a calculator using Python with addition , subtraction , multiplication ,division and power.


# This function adds two numbers
def add(a, b):
    return a + b

# This function subtracts two numbers
def subtract(a , b):
    return a - b

# This function multiplies two numbers
def multiply(a , b):
    return a * b

# This function divides two numbers
def divide(a , b):
    return a / b


print("Select Operation.")
print("1.Add")
print("2.Subtract")
print("3.Multiply")
print("4.Divide")

while True:
    # take input from the user
    choice = input("Enter choice(1/2/3/4): ")

    # check if choice is one of the four options
    if choice in ('1', '2', '3', '4'):
        num1 = float(input("Enter first number: "))
        num2 = float(input("Enter second number: "))

        if choice == '1':
            print(num1, "+", num2, "=", add(num1, num2))

        elif choice == '2':
            print(num1, "-", num2, "=", subtract(num1, num2))

        elif choice == '3':
            print(num1, "*", num2, "=", multiply(num1, num2))

        elif choice == '4':
            print(num1, "/", num2, "=", divide(num1, num2))
    
    else:
        print("Invalid Input")
# Out:
# Select Operation.
# 1.Add
# 2.Subtract
# 3.Multiply
# 4.Divide
# Enter choice(1/2/3/4): 1
# Enter first number: 12
# Enter second number: 12
# 12.0 + 12.0 = 24.0

# %%
# QUESTION 02
# Write a program to check if there is any numeric value in list using for loop.

number_list = [ 1, 6, 3, 5, 3, 4 ]
 
for i in number_list:
    if(i == 5) :
        print ("Element Exists")
# Out:
# Element Exists

# %%
# QUESTION 03
# Write a Python script to add a key to a dictionary.

dict = {'value1':'Noor', 'value2':'Developer'}
print("Current Dict is: ", dict)
  # using the subscript notation
# Dictionary_Name[New_Key_Name] = New_Key_Value
dict['value1'] = 'shaikh'
dict['value2'] = 'Ajam'
print("Updated Dict is: ", dict)
# Out:
# Current Dict is:  {'value1': 'Noor', 'value2': 'Developer'}
# Updated Dict is:  {'value1': 'shaikh', 'value2': 'Ajam'}

# %%
# QUESTION 04
# Write a Python program to sum all the numeric items in a dictionary.

def returnSum(myDict):
    dict_list = []
    for i in myDict:
        dict_list.append(myDict[i])
    final = sum(dict_list)
    return final
dict = {'a': 200, 'b':200}
print("Sum :", returnSum(dict))
# Out:
# Sum : 400

# %%
# QUESTION 05
# Write a program to identify duplicate values from list.
import collections
number_list = [1,3,3,1,1,5,6,9,5]
print([item for item, count in collections.Counter(number_list).items() 
       if count > 1])
# Out:
# [1, 3, 5]

# %%
# QUESTION 06
# Write a Python script to check if a given key already exists in a dictionary

def checkKey(dict, key):
    if key in dict.keys():
        print("Present, ", end =" ")
        print("value =", dict[key])
    else:
        print("Not present")

dict = {'a': 100, 'b':200, 'c':300}
key = 'b'
checkKey(dict, key)
# Out:
# Present,  value = 200
